# %% [markdown]
# # Exploring Cal Poly Schedules
# ## Using BeautifulSoup to parse schedules.calpoly.edu
# ### For PolyRooms

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "http://schedules.calpoly.edu/all_location_curr.htm"
r=requests.get(url)
soup=BeautifulSoup(r.content,'html.parser')
tableRows = soup.body.find("div", id="content").table.find_all("tr")

# %%
def rowFilter(tableRow):
    return False if len(tableRow) != 15 else True

# %%
tableRows=list(filter(rowFilter, tableRows))

# %%
print(len(tableRows))
print(tableRows)
# Out:
# 496
# [<tr>
# <th class="header" scope="col">Listing</th>
# <th class="header" scope="col">Schedule</th>
# <th class="header" scope="col"><abbr title="Registered Location Capacity">Loc Cap Reg</abbr></th>
# <th class="header" scope="col"><abbr title="Calculated Location Capacity">Loc Cap Calc</abbr></th>
# <th class="header" scope="col"><abbr title="Utilization Factor">Util Fact</abbr></th>
# <th class="header" scope="col"><abbr title="Optimal Factor">Opt Fact</abbr></th>
# <th class="headerICS" scope="col"><abbr title="Internet Calendaring and Scheduling File">ICS</abbr></th>
# </tr>, <tr>
# <td class="location"><a href="location_002-0013_curr.htm" title="Cotchett Education Room 0013">002-0013</a></td>
# <td class="location"><a href="schedule_002-0013_curr.htm">BD-002-0013</a></td>
# <td class="count">34</td>
# <td class="count">34</td>
# <td class="count">811</td>
# <td class="count">1190</td>
# ...
