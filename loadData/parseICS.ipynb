# %%
import pandas as pd
import requests
from icalendar import Calendar, Event

# %%
roomDF = pd.read_pickle('./rooms.pkl')
"""
for _, row in roomDF.iterrows():
    url  = "http://schedules.calpoly.edu" + row.ICS 
    ics  = requests.get(url)
"""
# get sample ics
urls  = "http://schedules.calpoly.edu" + roomDF.ICS
for url in urls[:5]:
    
    cal = Calendar.from_ical(requests.get(url).text)
    for component in cal.walk():
        if component.name == "VEVENT":
            print(component.get('dtstart').dt)
            print(component.get('dtend').dt)
            print(component.get('rrule'))
            print()
# Out:
# 2019-04-02 08:10:00-07:00
# 2019-04-02 09:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'TU', 'WE', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-02 09:10:00-07:00
# 2019-04-02 10:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'TU', 'WE', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-02 11:10:00-07:00
# 2019-04-02 12:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'TU', 'WE', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-03 14:10:00-07:00
# 2019-04-03 16:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-03 16:10:00-07:00
# 2019-04-03 17:30:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-03 18:10:00-07:00
# 2019-04-03 19:30:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-03 19:40:00-07:00
# 2019-04-03 21:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-03 12:10:00-07:00
# 2019-04-03 14:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-02 14:10:00-07:00
# 2019-04-02 15:30:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-02 15:40:00-07:00
# 2019-04-02 16:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-02 16:10:00-07:00
# 2019-04-02 17:30:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-02 18:10:00-07:00
# 2019-04-02 19:30:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-02 10:10:00-07:00
# 2019-04-02 11:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-02 12:10:00-07:00
# 2019-04-02 14:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0013
#
# 2019-04-08 14:10:00-07:00
# 2019-04-08 16:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO'], 'WKST': ['MO']})
# 002-0101
#
# 2019-04-03 12:10:00-07:00
# 2019-04-03 13:30:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0101
#
# 2019-04-02 14:10:00-07:00
# 2019-04-02 16:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU'], 'WKST': ['MO']})
# 002-0101
#
# 2019-04-02 12:10:00-07:00
# 2019-04-02 13:30:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0101
#
# 2019-04-03 14:10:00-07:00
# 2019-04-03 16:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-03 16:10:00-07:00
# 2019-04-03 18:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-03 18:10:00-07:00
# 2019-04-03 20:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-03 08:10:00-07:00
# 2019-04-03 10:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-03 10:10:00-07:00
# 2019-04-03 12:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-03 12:10:00-07:00
# 2019-04-03 14:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-03 12:10:00-07:00
# 2019-04-03 14:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['MO', 'WE'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-02 14:10:00-07:00
# 2019-04-02 16:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-02 16:10:00-07:00
# 2019-04-02 18:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-02 07:10:00-07:00
# 2019-04-02 09:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-02 09:10:00-07:00
# 2019-04-02 11:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-02 09:10:00-07:00
# 2019-04-02 11:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-02 12:10:00-07:00
# 2019-04-02 14:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU', 'TH'], 'WKST': ['MO']})
# 002-0113
#
# 2019-04-04 17:10:00-07:00
# 2019-04-04 19:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TH'], 'WKST': ['MO']})
# 002-0114
#
# 2019-04-04 07:10:00-07:00
# 2019-04-04 11:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TH'], 'WKST': ['MO']})
# 002-0114
#
# 2019-04-04 12:10:00-07:00
# 2019-04-04 15:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TH'], 'WKST': ['MO']})
# 002-0114
#
# 2019-04-02 17:10:00-07:00
# 2019-04-02 20:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TU'], 'WKST': ['MO']})
# 002-0114
#
# 2019-04-04 09:10:00-07:00
# 2019-04-04 11:00:00-07:00
# vRecur({'FREQ': ['WEEKLY'], 'UNTIL': [datetime.datetime(2019, 6, 8, 8, 0, tzinfo=<UTC>)], 'INTERVAL': [1], 'BYDAY': ['TH'], 'WKST': ['MO']})
# 002-0125
