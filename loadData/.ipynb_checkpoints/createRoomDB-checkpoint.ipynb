# %%
# this python code writes a dataframe with the room information to current directory
from bs4 import BeautifulSoup
import lxml.html as LH
import pandas as pd
import requests
import re

url = "http://schedules.calpoly.edu/all_location_curr.htm"
page = requests.get(url)
content = page.content

# remove rows with nonsense data
rowsSkip = [0]
pandasTable = pd.read_html(content, header = 0, skiprows = rowsSkip, keep_default_na = False)[0]
lhTable = LH.fromstring(content)

for index, row in pandasTable.iterrows():
    if(re.match(".*-.*",row['Listing']) is None):
        rowsSkip.append(index+2)
pandasTable = pd.read_html(page.content, header = 0, skiprows = rowsSkip, keep_default_na = False)[0]

# assign ICS href to ICS columns
icsHref = lhTable.xpath('//tr/td//a/@href')
icsRegex = re.compile(r'\/ics\/location.*')
icsHref = list(filter(icsRegex.match, icsHref))
pandasTable["ICS"] = icsHref
# get building names
buildingNames = []
roomNames = []
buildingRegex  = re.compile(r'(.+?)[-\s].*')
roomRegex = re.compile(r'.*[-](.+)')
for index, row in pandasTable.iterrows():
    text = row.Listing
    buildingFound = buildingRegex.search(text)
    roomFound = roomRegex.search(text)
    if buildingFound:
        building = buildingFound.group(1)
        buildingNames.append(building)
    if roomFound:
        room = roomFound.group(1)
        roomNames.append(room)

# add building names
pandasTable.insert(loc = 1, column = 'Building', value = buildingNames, allow_duplicates = True)
pandasTable.insert(loc = 2, column = 'Room', value = roomNames, allow_duplicates = True)
# drop unnecessary columns
pandasTable = pandasTable.drop(columns = ['Schedule', 'Loc Cap Calc', 'Util Fact', 'Opt Fact'])
# drop rows with 99x
dropRowsRegex = re.compile(r'99.*')
for index, row in pandasTable.iterrows():
    if(dropRowsRegex.match(row['Listing']) is None):
        
pandasTable = pd.read_html(page.content, header = 0, skiprows = rowsSkip, keep_default_na = False)[0]

print(pandasTable)
# Out:
#                                     Listing Building  \
# 0                                  002-0013      002
# 1                                  002-0101      002
# 2                              002-0113 (2)      002
# 3                                  002-0114      002
# 4                                  002-0125      002
# 5                                  002-0126      002
# 6                                  002-0127      002
# 7                                  002-0203      002
# 8                                  002-0204      002
# 9                                  002-0205      002
# 10                             002-0210 (3)      002
# 11                             002-0212 (2)      002
# 12                                 002-0213      002
# 13                                 002-0214      002
# 14                                 003-0104      003
# 15                                 003-0111      003
# 16                                 003-0112      003
# 17                                 003-0113      003
# 18                                 003-0114      003
# 19                                 003-0201      003
# 20                                 003-0204      003
# 21                                 003-0205      003
# 22                                 003-0206      003
# 23                                 003-0209      003
# 24                             003-0213 (9)      003
# 25                                003-0300A      003
# 26                                 003-0302      003
# 27                                 003-0303      003
# 28                                 003-0305      003
# 29                                 003-0306      003
# ..                                      ...      ...
# 417                                192-0118      192
# 418                                192-0120      192
# 419                                192-0121      192
# 420                            192-0131 (9)      192
# 421                                192-0132      192
# 422                            192-0134 (6)      192
# 423                                192-0135      192
# 424                                192-0136      192
# 425                            192-0204 (4)      192
# 426                            192-0205 (4)      192
# 427                                192-0208      192
# 428                                192-0209      192
# 429                            192-0220 (2)      192
# 430                            192-0221 (2)      192
# 431                            192-0224 (2)      192
# 432                                192-0239      192
# 433                                192-0240      192
# 434                                192-0242      192
# 435                                192-0321      192
# 436                                192-0322      192
# 437                                192-0323      192
# 438                                192-0327      192
# 439                                192-0328      192
# 440                            192-0329 (2)      192
# 441                                192-0330      192
# 442                                192-0331      192
# 443                                192-0333      192
# 444              997 On-Campus  997 EMIList      997
# 445  998 On-Campus Unspecified  998 EMIList      998
# 446             999 Off-Campus  999 EMIList      999
#
#                                 Room Loc Cap Reg  \
# 0                               0013          34
# 1                               0101          30
# 2                           0113 (2)          30
# 3                               0114          36
# 4                               0125          20
# 5                               0126          50
# 6                               0127          54
# 7                               0203          46
# 8                               0204          46
# 9                               0205          30
# 10                          0210 (3)          45
# 11                          0212 (2)          49
# 12                              0213          40
# 13                              0214          48
# 14                              0104          25
# 15                              0111          68
# 16                              0112          68
# 17                              0113          46
# 18                              0114          40
# 19                              0201          42
# 20                              0204          45
# 21                              0205          45
# 22                              0206          46
# 23                              0209          46
# 24                          0213 (9)         230
# 25                             0300A          44
# 26                              0302          41
# 27                              0303          36
# 28                              0305          48
# 29                              0306          38
# ..                               ...         ...
# 417                             0118          24
# 418                             0120          36
# 419                             0121          24
# 420                         0131 (9)          18
# 421                             0132          24
# 422                         0134 (6)          18
# 423                             0135          12
# 424                             0136          24
# 425                         0204 (4)          16
# 426                         0205 (4)          24
# 427                             0208          16
# 428                             0209          24
# 429                         0220 (2)          36
# 430                         0221 (2)          24
# 431                         0224 (2)          43
# 432                             0239          25
# 433                             0240          30
# 434                             0242          36
# 435                             0321          24
# 436                             0322          24
# 437                             0323          24
# 438                             0327          24
# 439                             0328          24
# 440                         0329 (2)          48
# 441                             0330          24
# 442                             0331          48
# 443                             0333          24
# 444              Campus  997 EMIList
# 445  Campus Unspecified  998 EMIList
# 446              Campus  999 EMIList
#
#                                   ICS
# 0     /ics/location_002-0013-2194.ics
# 1     /ics/location_002-0101-2194.ics
# 2     /ics/location_002-0113-2194.ics
# 3     /ics/location_002-0114-2194.ics
# 4     /ics/location_002-0125-2194.ics
# 5     /ics/location_002-0126-2194.ics
# 6     /ics/location_002-0127-2194.ics
# 7     /ics/location_002-0203-2194.ics
# 8     /ics/location_002-0204-2194.ics
# 9     /ics/location_002-0205-2194.ics
# 10    /ics/location_002-0210-2194.ics
# 11    /ics/location_002-0212-2194.ics
# 12    /ics/location_002-0213-2194.ics
# 13    /ics/location_002-0214-2194.ics
# 14    /ics/location_003-0104-2194.ics
# 15    /ics/location_003-0111-2194.ics
# 16    /ics/location_003-0112-2194.ics
# 17    /ics/location_003-0113-2194.ics
# 18    /ics/location_003-0114-2194.ics
# 19    /ics/location_003-0201-2194.ics
# 20    /ics/location_003-0204-2194.ics
# 21    /ics/location_003-0205-2194.ics
# 22    /ics/location_003-0206-2194.ics
# 23    /ics/location_003-0209-2194.ics
# 24    /ics/location_003-0213-2194.ics
# 25   /ics/location_003-0300A-2194.ics
# 26    /ics/location_003-0302-2194.ics
# 27    /ics/location_003-0303-2194.ics
# 28    /ics/location_003-0305-2194.ics
# 29    /ics/location_003-0306-2194.ics
# ..                                ...
# 417   /ics/location_192-0118-2194.ics
# 418   /ics/location_192-0120-2194.ics
# 419   /ics/location_192-0121-2194.ics
# 420   /ics/location_192-0131-2194.ics
# 421   /ics/location_192-0132-2194.ics
# 422   /ics/location_192-0134-2194.ics
# 423   /ics/location_192-0135-2194.ics
# 424   /ics/location_192-0136-2194.ics
# 425   /ics/location_192-0204-2194.ics
# 426   /ics/location_192-0205-2194.ics
# 427   /ics/location_192-0208-2194.ics
# 428   /ics/location_192-0209-2194.ics
# 429   /ics/location_192-0220-2194.ics
# 430   /ics/location_192-0221-2194.ics
# 431   /ics/location_192-0224-2194.ics
# 432   /ics/location_192-0239-2194.ics
# 433   /ics/location_192-0240-2194.ics
# 434   /ics/location_192-0242-2194.ics
# 435   /ics/location_192-0321-2194.ics
# 436   /ics/location_192-0322-2194.ics
# 437   /ics/location_192-0323-2194.ics
# 438   /ics/location_192-0327-2194.ics
# 439   /ics/location_192-0328-2194.ics
# 440   /ics/location_192-0329-2194.ics
# 441   /ics/location_192-0330-2194.ics
# 442   /ics/location_192-0331-2194.ics
# 443   /ics/location_192-0333-2194.ics
# 444        /ics/location_997-2194.ics
# 445        /ics/location_998-2194.ics
# 446        /ics/location_999-2194.ics
#
# [447 rows x 5 columns]
