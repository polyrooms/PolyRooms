# %%
import pandas as pd
import ics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-44eb3b79682b> in <module>()
#       1 import pandas as pd
# ----> 2 import ics
#
# ModuleNotFoundError: No module named 'ics'

# %%
roomDF = pd.read_pickle('./rooms.pkl')
# for each row, get ICS
# Out:
#                                     Listing Loc Cap Reg  \
# 0                                  002-0013          34
# 1                                  002-0101          30
# 2                              002-0113 (2)          30
# 3                                  002-0114          36
# 4                                  002-0125          20
# 5                                  002-0126          50
# 6                                  002-0127          54
# 7                                  002-0203          46
# 8                                  002-0204          46
# 9                                  002-0205          30
# 10                             002-0210 (3)          45
# 11                             002-0212 (2)          49
# 12                                 002-0213          40
# 13                                 002-0214          48
# 14                                 003-0104          25
# 15                                 003-0111          68
# ...
